# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import r2_score,root_mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("latence_reseau.csv", sep=(";"))

# %%
df.head()
# Out:
#    Bande_passante_Mbps  Distance_km  Taux_utilisation_%  Nombre_sauts  \
# 0                   10            2                  30             2
# 1                   20            5                  40             3
# 2                   50           10                  60             4
# 3                  100           15                  70             5
# 4                  100            5                  30             2
#
#    Type_lien  Latence_ms
# 0          0          18
# 1          0          25
# 2          0          40
# 3          0          55
# 4          1          12

# %%
df.describe()
# Out:
#        Bande_passante_Mbps  Distance_km  Taux_utilisation_%  Nombre_sauts  \
# count            17.000000    17.000000           17.000000     17.000000
# mean             91.176471    12.352941           54.705882      3.705882
# std              79.599180     8.992644           23.549853      1.794600
# min              10.000000     1.000000           10.000000      1.000000
# 25%              30.000000     5.000000           40.000000      2.000000
# 50%              60.000000    10.000000           60.000000      4.000000
# 75%             100.000000    20.000000           70.000000      5.000000
# max             300.000000    30.000000           90.000000      7.000000
#
#        Type_lien  Latence_ms
# count  17.000000   17.000000
# mean    0.823529   34.647059
# std     0.808957   18.272046
# min     0.000000    9.000000
# 25%     0.000000   18.000000
# 50%     1.000000   32.000000
# 75%     1.000000   48.000000
# max     2.000000   68.000000

# %%
df.isnull().sum()
# Out:
# Bande_passante_Mbps    0
# Distance_km            0
# Taux_utilisation_%     0
# Nombre_sauts           0
# Type_lien              0
# Latence_ms             0
# dtype: int64

# %%
L = plt.xlabel("Latence_ms")
D = plt.ylabel("Distance_km")
plt.scatter(df["Latence_ms"],df["Distance_km"], color = "yellow")

# %%
L = plt.xlabel("Latence_ms")
T = plt.ylabel("Taux_utiilisation_%")
plt.scatter(df["Latence_ms"],df["Taux_utilisation_%"], color = "yellow")

# %%
L = plt.xlabel("Latence_ms")
B = plt.ylabel("Bande_passante_Mbps")
plt.scatter(df["Latence_ms"],df["Bande_passante_Mbps"], color = "yellow")

# %%
x = df[['Bande_passante_Mbps','Distance_km','Taux_utilisation_%','Nombre_sauts','Type_lien']]

# %%
y = df['Latence_ms']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2, random_state = 42)

# %%
lr = linear_model.LinearRegression()
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
data = lr.predict(x_test)

# %%
data
# Out:
# array([28.73747075, 38.88804318, 17.39413572, 53.98873531])

# %%
print("r2_score :", (y_test, data))
# Out:
# r2_score : (0     18
# 1     25
# 5     18
# 15    60
# Name: Latence_ms, dtype: int64, array([28.73747075, 38.88804318, 17.39413572, 53.98873531]))

# %%
print("RMSE : " , root_mean_squared_error(y_test, data))
# Out:
# RMSE :  9.282690829894452

# %%
print("MAE  : ",mean_absolute_error(y_test,data))
# Out:
# MAE  :  7.810660723119916

# %% [markdown]
# ##
